# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load csv
df = pd.read_csv("temphum.csv")

# %%
df
# Out:
#                  Time   Humidity
# 0    11.09.2018 14:26  50.378418
# 1    11.09.2018 14:27  50.079346
# 2    11.09.2018 14:27  52.368164
# 3    11.09.2018 14:28  55.651855
# 4    11.09.2018 14:28  59.106445
# 5    11.09.2018 14:29  62.890625
# 6    11.09.2018 14:30  66.772461
# 7    11.09.2018 14:30  70.819092
# 8    11.09.2018 14:31  73.602295
# 9    11.09.2018 14:32  74.798584
# 10   11.09.2018 14:32  75.396729
# 11   11.09.2018 14:33  75.292969
# 12   11.09.2018 14:34  74.798584
# 13   11.09.2018 14:34  74.200439
# 14   11.09.2018 14:35  73.602295
# 15   11.09.2018 14:36  73.004150
# 16   11.09.2018 14:36  72.509766
# 17   11.09.2018 14:37  71.911621
# 18   11.09.2018 14:37  71.313477
# 19   11.09.2018 14:38  70.721436
# 20   11.09.2018 14:39  70.220947
# 21   11.09.2018 14:39  69.726562
# 22   11.09.2018 14:40  69.091797
# 23   11.09.2018 14:41  68.597412
# 24   11.09.2018 14:41  68.103027
# 25   11.09.2018 14:42  67.602539
# 26   11.09.2018 14:43  67.108154
# ...

# %% [markdown]
# Read excel-files

# %%
from openpyxl import load_workbook
wb = load_workbook('measurement DECONX162 2018-09-11.xlsx')

# %%
print(wb.get_sheet_names())
# Out:
# ['all', 'RH']
# C:\Users\bsingstad\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function get_sheet_names (Use wb.sheetnames).
#   """Entry point for launching an IPython kernel.

# %%
# Get a sheet by name 
sheet = wb.get_sheet_by_name('RH')

# Print the sheet title 
sheet.title
# Out:
# C:\Users\bsingstad\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
# 'RH'

# %%
# Retrieve the value of a certain cell
sheet['A1'].value

# Select element 'B2' of your sheet 
c = sheet['B2']

# Retrieve the row number of your element
c.row

# Retrieve the column letter of your element
c.column

# Retrieve the coordinates of the cell 
c.coordinate
# Out:
# 'B2'

# %%
c
# Out:
# <Cell 'RH'.B2>

# %%
k=sheet['A1'].value
k
# Out:
# 'timestamp'

# %%
# Retrieve cell value 
sheet.cell(row=1, column=2).value

# Print out values in column 2 
for i in range(1, 10):
     print(i, sheet.cell(row=i, column=2).value)
# Out:
# 1 value
# 2 118.998092651367
# 3 118.998092651367
# 4 118.998092651367
# 5 49.652099609375
# 6 53.515625
# 7 50.0244140625
# 8 54.754638671875
# 9 54.132080078125

# %%
# Import relevant modules from `openpyxl.utils`
from openpyxl.utils import get_column_letter, column_index_from_string

# Return 'A'
get_column_letter(1)

# Return '1'
column_index_from_string('A')
# Out:
# 1

# %%
excelframe = pd.DataFrame(sheet.values)

# %%
excelframe
# Out:
#                         0        1                  2  \
# 0               timestamp    value         id_machine
# 1     2018-07-11 09:53:06  118.998  SERVICE-DECONX162
# 2     2018-07-11 10:53:22  118.998  SERVICE-DECONX162
# 3     2018-07-11 11:53:37  118.998  SERVICE-DECONX162
# 4     2018-07-17 13:49:52  49.6521  SERVICE-DECONX162
# 5     2018-07-17 13:52:22  53.5156  SERVICE-DECONX162
# 6     2018-07-17 13:52:59  50.0244  SERVICE-DECONX162
# 7     2018-08-09 08:26:19  54.7546  SERVICE-DECONX162
# 8     2018-08-09 08:38:39  54.1321  SERVICE-DECONX162
# 9     2018-08-09 08:39:18  54.4312  SERVICE-DECONX162
# 10    2018-08-09 08:39:57  54.5288  SERVICE-DECONX162
# 11    2018-08-09 08:40:35  56.9214  SERVICE-DECONX162
# 12    2018-08-09 08:41:13  59.7046  SERVICE-DECONX162
# 13    2018-08-09 08:41:52  62.6648  SERVICE-DECONX162
# 14    2018-08-09 08:42:31  65.8447  SERVICE-DECONX162
# 15    2018-08-09 08:43:09  69.2261  SERVICE-DECONX162
# ...

# %% [markdown]
# Select only the column with humidity and remove data points from earlier measurements:

# %%
a=excelframe.iloc[971:,1:2]

# %%
a
# Out:
#             1
# 971   50.3784
# 972   50.0793
# 973   52.3682
# 974   55.6519
# 975   59.1064
# 976   62.8906
# 977   66.7725
# 978   70.8191
# 979   73.6023
# 980   74.7986
# 981   75.3967
# 982    75.293
# 983   74.7986
# 984   74.2004
# 985   73.6023
# 986   73.0042
# 987   72.5098
# 988   71.9116
# 989   71.3135
# 990   70.7214
# 991   70.2209
# 992   69.7266
# 993   69.0918
# 994   68.5974
# 995    68.103
# 996   67.6025
# 997   67.1082
# 998   66.6077
# 999   66.2109
# 1000  65.9119
# ...       ...
# 1043  58.5999
# 1044  58.5266
# 1045  58.3984
# 1046  58.3313
# 1047  58.3008
# 1048  58.2275
# 1049  58.1299
# 1050  58.1299
# 1051  58.0322
# 1052  57.9285
# 1053  57.9285
# 1054  57.8308
# 1055  57.8308
# 1056  57.7332
# 1057  57.7332
# 1058  57.6355
# 1059  57.6355
# 1060  57.5317
# 1061  57.5317
# 1062  57.4341
# 1063  57.4341
# 1064  57.4341
# 1065  57.4341
# 1066  57.3364
# 1067  57.3364
# 1068  57.3364
# 1069  57.2388
# 1070  57.2388
# 1071  57.2388
# 1072  56.8176
#
# ...

# %%
print(type(excelframe))
print(type(a))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# Create numpy array from pandas dataframe:

# %%
l=np.array(a)

# %%
l
# Out:
# array([[50.37841796875],
#        [50.079345703125],
#        [52.3681640625],
#        [55.65185546875],
#        [59.1064453125],
#        [62.890625],
#        [66.7724609375],
#        [70.819091796875],
#        [73.602294921875],
#        [74.798583984375],
#        [75.396728515625],
#        [75.29296875],
#        [74.798583984375],
#        [74.200439453125],
#        [73.602294921875],
#        [73.004150390625],
#        [72.509765625],
#        [71.91162109375],
#        [71.3134765625],
#        [70.721435546875],
#        [70.220947265625],
#        [69.7265625],
#        [69.091796875],
#        [68.597412109375],
#        [68.10302734375],
#        [67.6025390625],
#        [67.108154296875],
#        [66.607666015625],
#        [66.2109375],
#        [65.911865234375],
#        [65.51513671875],
#        [65.216064453125],
#        [64.9169921875],
#        [64.617919921875],
#        [64.324951171875],
#        [64.02587890625],
#        [63.6962890625],
# ...

# %%
plt.plot(l, 'ro')

# %%
datalogger1 = load_workbook('Datalogger1_11sept_2018.xlsx')

# %%
print(datalogger1.get_sheet_names())
# Out:
# ['Diagram1', 'Data']
# C:\Users\bsingstad\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function get_sheet_names (Use wb.sheetnames).
#   """Entry point for launching an IPython kernel.

# %%
templog1 = datalogger1.get_sheet_by_name('Data')
# Out:
# C:\Users\bsingstad\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
#   """Entry point for launching an IPython kernel.

# %%
templogger1 = pd.DataFrame(templog1.values)

# %%
templogger1
# Out:
#                  0                    1            2              3   \
# 0      EasyLog USB1                 Time  Celsius(°C)  Humidity(%rh)
# 1                 1  2018-09-11 11:26:23           23           53.5
# 2                 2  2018-09-11 11:26:33         23.5           63.5
# 3                 3  2018-09-11 11:26:43         23.5             63
# 4                 4  2018-09-11 11:26:53         23.5             57
# 5                 5  2018-09-11 11:27:03         23.5           54.5
# 6                 6  2018-09-11 11:27:13         23.5             53
# 7                 7  2018-09-11 11:27:23           24           52.5
# 8                 8  2018-09-11 11:27:33           24           52.5
# 9                 9  2018-09-11 11:27:43           24             59
# 10               10  2018-09-11 11:27:53           24           57.5
# 11               11  2018-09-11 11:28:03           24             54
# 12               12  2018-09-11 11:28:13         24.5             52
# ...

# %%
b=templogger1.iloc[1250:,2:4]
b
# Out:
#           2     3
# 1250     26  47.5
# 1251     26  47.5
# 1252   25.5  47.5
# 1253   25.5  47.5
# 1254   25.5  47.5
# 1255   25.5    47
# 1256     25  47.5
# 1257     25  48.5
# 1258     25  49.5
# 1259     25  50.5
# 1260   24.5    51
# 1261   24.5  51.5
# 1262   24.5    52
# 1263   24.5  52.5
# 1264   24.5    53
# 1265   24.5    53
# 1266   24.5  53.5
# 1267     24    54
# 1268     24    54
# 1269     24  54.5
# 1270     24  54.5
# 1271     24    55
# 1272     24    55
# 1273     24  55.5
# 1274     24  55.5
# 1275     24    56
# 1276     24    56
# 1277     24    56
# 1278     24    56
# 1279     24  56.5
# ...     ...   ...
# 65506  None  None
# 65507  None  None
# 65508  None  None
# 65509  None  None
# 65510  None  None
# 65511  None  None
# 65512  None  None
# 65513  None  None
# 65514  None  None
# 65515  None  None
# 65516  None  None
# 65517  None  None
# 65518  None  None
# 65519  None  None
# 65520  None  None
# 65521  None  None
# 65522  None  None
# 65523  None  None
# ...

# %%
plt.plot(a)
plt.plot(b)
plt.show()

# %% [markdown]
# Test med forskjellige timestamps:
